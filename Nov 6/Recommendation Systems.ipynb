# %%
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import pandas as pd
import numpy as np
import torch
# Out:
# Error importing huggingface_hub.hf_api: cannot import name 'BaseFileLock' from 'filelock' (C:\Users\dai\AppData\Roaming\Python\Python313\site-packages\filelock\__init__.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 from tqdm import tqdm
#       3 import pandas as pd
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
# ...
