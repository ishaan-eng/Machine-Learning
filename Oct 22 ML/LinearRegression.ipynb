# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
df=pd.read_csv("Housing.csv")
dh=pd.get_dummies(df,drop_first=True)
x=df.drop('price',axis=1)
y=df['price']
lr=LinearRegression()
lr.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21764\1376111059.py in ?()
#       7 dh=pd.get_dummies(df,drop_first=True)
#       8 x=df.drop('price',axis=1)
#       9 y=df['price']
#      10 lr=LinearRegression()
# ---> 11 lr.fit(x,y)
#      12
#
# ~\PycharmProjects\PythonLab\.venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~\PycharmProjects\PythonLab\.venv\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
#     615
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
concrete=pd.read_csv("Concrete_Data.csv")
x=concrete.drop('Strength',axis=1)
y=concrete['Strength']
lr=LinearRegression()
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=25)
lr.fit(X_train,y_train)
lr.predict(X_test)
lr.score(X_test,y_test)
mean_absolute_error(lr.predict(X_test),y_test)
# Out:
# 7.708182724272727

# %%
poly=PolynomialFeatures(degree=2)
X_poly=poly.fit_transform(x)

X_train,X_test,y_train,y_test=train_test_split(X_poly,y,test_size=0.3,random_state=25)
lr.fit(X_train,y_train)
ya=lr.predict(X_test)
mean_absolute_error(ya,y_test)
# Out:
# 5.92992227653092

# %%
poly=PolynomialFeatures(degree=3,include_bias=False)
X_poly=poly.fit_transform(x)

X_train,X_test,y_train,y_test=train_test_split(X_poly,y,test_size=0.3,random_state=25)
lr.fit(X_train,y_train)
ya=lr.predict(X_test)
mean_absolute_error(ya,y_test)
# Out:
# 5.186728770796333

# %%
poly=PolynomialFeatures(degree=4,include_bias=False)
X_poly=poly.fit_transform(x)

X_train,X_test,y_train,y_test=train_test_split(X_poly,y,test_size=0.3,random_state=25)
lr.fit(X_train,y_train)
ya=lr.predict(X_test)
mean_absolute_error(ya,y_test)
# Out:
# 22.60895752526373

# %%
poly=PolynomialFeatures(degree=3,include_bias=False)
X_poly=poly.fit_transform(x)
lr.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
tst=pd.read_csv("testConcrete.csv")
tst_poly=poly.transform(tst)
lr.predict(tst_poly)
# Out:
# array([  39.10981425,   -6.21622698,  107.15204619, -165.57127798,
#         156.19364943, 1044.45048998,  110.16175236,  142.0645652 ,
#         342.42832565,  879.46365749,   62.44653143,  448.73640089,
#        -116.59714253,  477.8611563 ])

# %%
saZ
boston=pd.read_csv("boston.csv")
X=boston.drop('medv',axis=1)
y=boston['medv']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=25)
ridge=Ridge()
ridge.fit(X_train,y_train)
y_pred=ridge.predict(X_test)
mean_absolute_error(y_pred,y_test)
# Out:
# 3.0710068015709453

# %%
alphas=[0.001,0.01,0.1,0.5,1,1.5,2,2.5,5,10]
scores=[]
for a in alphas:
    ridge=Ridge(alpha=a)
    ridge.fit(X_train,y_train)
    y_pred=ridge.predict(X_test)
    scores.append([a,mean_absolute_error(y_pred,y_test)])
    print(f"alpha={a}, Error={mean_absolute_error(y_pred,y_test)}")
df_scores=pd.DataFrame(scores,columns=['alpha','error'])
df_scores.sort_values('error')
# Out:
# alpha=0.001, Error=3.1173729732361632
# alpha=0.01, Error=3.115620955071867
# alpha=0.1, Error=3.100479135289701
# alpha=0.5, Error=3.072121490013463
# alpha=1, Error=3.0710068015709453
# alpha=1.5, Error=3.0736609820107703
# alpha=2, Error=3.0775098627987423
# alpha=2.5, Error=3.0825628553157087
# alpha=5, Error=3.102838380345656
# alpha=10, Error=3.124733243663749
#     alpha     error
# 4   1.000  3.071007
# 3   0.500  3.072121
# 5   1.500  3.073661
# 6   2.000  3.077510
# 7   2.500  3.082563
# 2   0.100  3.100479
# 8   5.000  3.102838
# 1   0.010  3.115621
# 0   0.001  3.117373
# 9  10.000  3.124733

# %%
scores=[]
for a in alphas:
    lasso=Lasso(alpha=a)
    lasso.fit(X_train,y_train)
    y_pred=lasso.predict(X_test)
    scores.append([a,mean_absolute_error(y_pred,y_test)])
    print(f"alpha={a}, Error={mean_absolute_error(y_pred,y_test)}")
df_scores=pd.DataFrame(scores,columns=['alpha','error'])
df_scores.sort_values('error')
# Out:
# alpha=0.001, Error=3.1141997713387974
# alpha=0.01, Error=3.0882213067555164
# alpha=0.1, Error=3.129219010236669
# alpha=0.5, Error=3.197793654966185
# alpha=1, Error=3.373066457654744
# alpha=1.5, Error=3.5429214954786126
# alpha=2, Error=3.5731084764971923
# alpha=2.5, Error=3.6321834695038824
# alpha=5, Error=3.8562936360495628
# alpha=10, Error=3.9421404721359834
#     alpha     error
# 1   0.010  3.088221
# 0   0.001  3.114200
# 2   0.100  3.129219
# 3   0.500  3.197794
# 4   1.000  3.373066
# 5   1.500  3.542921
# 6   2.000  3.573108
# 7   2.500  3.632183
# 8   5.000  3.856294
# 9  10.000  3.942140

# %%
alphas=[0.001,0.01,0.1,0.5,1,1.5,2,2.5,5,10]
ratios=[0.001,0.25,0.5,0.75,1]
scores=[]
for a in alphas:
    for r in ratios:
        elastic=ElasticNet(alpha=a,l1_ratio=r)
        elastic.fit(X_train,y_train)
        y_pred=elastic.predict(X_test)
        scores.append([a,r,mean_absolute_error(y_pred,y_test)])
        print(f"alpha={a}, Error={mean_absolute_error(y_pred,y_test)}")
df_scores=pd.DataFrame(scores,columns=['alpha','l1_ratio','error'])
df_scores.sort_values('error')
# Out:
# alpha=0.001, Error=3.077351055668457
# alpha=0.001, Error=3.0823042089190134
# alpha=0.001, Error=3.08947309077556
# alpha=0.001, Error=3.1001388192910855
# alpha=0.001, Error=3.1141997713387974
# alpha=0.01, Error=3.0922375961710826
# alpha=0.01, Error=3.0858066517146554
# alpha=0.01, Error=3.0791642286348564
# alpha=0.01, Error=3.071907959282224
# alpha=0.01, Error=3.0882213067555164
# alpha=0.1, Error=3.1864681737744016
# alpha=0.1, Error=3.179851288319145
# alpha=0.1, Error=3.167589291286785
# alpha=0.1, Error=3.14992208605722
# alpha=0.1, Error=3.129219010236669
# alpha=0.5, Error=3.349475357142678
# alpha=0.5, Error=3.3339511356306972
# alpha=0.5, Error=3.3064501160415114
# alpha=0.5, Error=3.266076915320074
# alpha=0.5, Error=3.197793654966185
# alpha=1, Error=3.422454737277787
# alpha=1, Error=3.4171966220093295
# alpha=1, Error=3.4080058775996527
# alpha=1, Error=3.395275761552456
# alpha=1, Error=3.373066457654744
# alpha=1.5, Error=3.4551210779024055
# ...

# %%
concrete=pd.read_csv("Concrete_Data.csv")
x=concrete.drop('Strength',axis=1)
y=concrete['Strength']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=25)
alphas=[0.001,0.01,0.1,0.5,1,1.5,2,2.5,5,10]
ratios=[0.001,0.25,0.5,0.75,1]
scores=[]
for a in alphas:
    for r in ratios:
        elastic=ElasticNet(alpha=a,l1_ratio=r)
        elastic.fit(X_train,y_train)
        y_pred=elastic.predict(X_test)
        scores.append([a,r,mean_absolute_error(y_pred,y_test)])
        print(f"alpha={a}, Error={mean_absolute_error(y_pred,y_test)}")
df_scores=pd.DataFrame(scores,columns=['alpha','l1_ratio','error'])
df_scores.sort_values('error')
# Out:
# alpha=0.001, Error=7.708184006627304
# alpha=0.001, Error=7.708187446160385
# alpha=0.001, Error=7.708190898536301
# alpha=0.001, Error=7.708194354867756
# alpha=0.001, Error=7.7081978126317185
# alpha=0.01, Error=7.708195533473656
# alpha=0.01, Error=7.708229916892009
# alpha=0.01, Error=7.708264485420922
# alpha=0.01, Error=7.70829899750611
# alpha=0.01, Error=7.7083335801644886
# alpha=0.1, Error=7.70830939820839
# alpha=0.1, Error=7.7086528180276614
# alpha=0.1, Error=7.7089981593902905
# alpha=0.1, Error=7.709343784074201
# alpha=0.1, Error=7.709690672709038
# alpha=0.5, Error=7.7087859637796425
# alpha=0.5, Error=7.7104897047957675
# alpha=0.5, Error=7.712215352017724
# alpha=0.5, Error=7.7139585638690775
# alpha=0.5, Error=7.715713664590085
# alpha=1, Error=7.709319778882726
# alpha=1, Error=7.712696218798085
# alpha=1, Error=7.716144404955734
# alpha=1, Error=7.719651550209179
# alpha=1, Error=7.723270793572215
# alpha=1.5, Error=7.709792927802878
# ...

# %%
from sklearn.impute import SimpleImputer
job=pd.read_csv("JobSalary2.csv",index_col=0)
job.isnull().sum()
# Out:
# Computer     2
# Marketing    1
# Engineer     0
# dtype: int64

# %%
imputer=SimpleImputer(strategy="mean").set_output(transform="pandas")
imputer.fit(job)#Cals mean of every column
imputer.statistics_
# Out:
# array([75.33333333, 52.57142857, 85.625     ])

# %%
imputer.transform(job)
# Out:
#        Computer  Marketing  Engineer
# S_No
# 1     84.000000  55.000000      75.0
# 2     90.000000  53.000000      70.0
# 3     63.000000  52.571429      88.0
# 4     75.333333  50.000000      77.0
# 5     63.000000  41.000000      89.0
# 6     75.000000  54.000000      85.0
# 7     75.333333  51.000000      96.0
# 8     77.000000  64.000000     105.0

# %%
imputer.fit_transform(job)
# Out:
#        Computer  Marketing  Engineer
# S_No
# 1     84.000000  55.000000      75.0
# 2     90.000000  53.000000      70.0
# 3     63.000000  52.571429      88.0
# 4     75.333333  50.000000      77.0
# 5     63.000000  41.000000      89.0
# 6     75.000000  54.000000      85.0
# 7     75.333333  51.000000      96.0
# 8     77.000000  64.000000     105.0

# %%
concrete=pd.read_csv("Concrete_Data.csv")
X=concrete.drop('Strength',axis=1)
y=concrete['Strength']
lr=LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
concrete=pd.read_csv("testConcreteMissing.csv")
X=concrete.drop('Strength',axis=1)
y=concrete['Strength']
lr=LinearRegression()
lr.fit(X,y)
y_pred=lr.predict(X)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 2
#       1 concrete=pd.read_csv("testConcreteMissing.csv")
# ----> 2 X=concrete.drop('Strength',axis=1)
#       3 y=concrete['Strength']
#       4 lr=LinearRegression()
#
# File ~\PycharmProjects\PythonLab\.venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
# ...

# %%
imputer=SimpleImputer().set_output(transform="pandas")
imputer.fit(X)
tst_imp=imputer.transform(tst)
lr.predict(tst_imp)
# Out:
# array([68.73718457, 31.79087677, 19.49398729, 46.85251608, 58.04081121,
#        16.09260432, 50.35570736, 80.30956659, 31.1332727 , 41.56603327,
#        43.44332935, 60.76906843, 52.37399367, 15.38709673])

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
chem=pd.read_csv("ChemicalProcess.csv")
y=chem['Yield']
X=chem.drop('Yield',axis=1)
X.isnull().sum()
# Out:
# BiologicalMaterial01       0
# BiologicalMaterial02       0
# BiologicalMaterial03       0
# BiologicalMaterial04       0
# BiologicalMaterial05       0
# BiologicalMaterial06       0
# BiologicalMaterial07       0
# BiologicalMaterial08       0
# BiologicalMaterial09       0
# BiologicalMaterial10       0
# BiologicalMaterial11       0
# BiologicalMaterial12       0
# ManufacturingProcess01     1
# ManufacturingProcess02     3
# ManufacturingProcess03    15
# ManufacturingProcess04     1
# ManufacturingProcess05     1
# ManufacturingProcess06     2
# ManufacturingProcess07     1
# ManufacturingProcess08     1
# ManufacturingProcess09     0
# ManufacturingProcess10     9
# ManufacturingProcess11    10
# ManufacturingProcess12     1
# ManufacturingProcess13     0
# ManufacturingProcess14     1
# ManufacturingProcess15     0
# ManufacturingProcess16     0
# ManufacturingProcess17     0
# ManufacturingProcess18     0
# ManufacturingProcess19     0
# ManufacturingProcess20     0
# ...

# %%
y.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
X.isnull().sum().sum()
# Out:
# np.int64(106)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=25)

# %%
X_train.isnull().sum().sum()
# Out:
# np.int64(80)

# %%
X_test.isnull().sum().sum()
# Out:
# np.int64(26)

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy="mean").set_output(transform="pandas")
imputer.fit(X_train)
X_train_imp=imputer.transform(X_train)
X_test_imp=imputer.transform(X_test)

# %%
X_train_imp.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
X_test_imp.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
lr=LinearRegression()
lr.fit(X_train_imp,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test_imp)
mean_absolute_error(y_pred,y_test)
# Out:
# 5.46562888453617

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
chem=pd.read_csv("ChemicalProcess.csv")
y=chem['Yield']
X=chem.drop('Yield',axis=1)
X.isnull().sum()
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=25)
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy="median").set_output(transform="pandas")
imputer.fit(X_train)
X_train_imp=imputer.transform(X_train)
X_test_imp=imputer.transform(X_test)
lr=LinearRegression()
lr.fit(X_train_imp,y_train)
y_pred=lr.predict(X_test_imp)
mean_absolute_error(y_pred,y_test)
# Out:
# 5.2164386091805754

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer=IterativeImputer(initial_strategy='mean',random_state=25)
imputer.fit(X_train)
X_train_imp=imputer.transform(X_train)
X_test_imp=imputer.transform(X_test)
lr=LinearRegression()
lr.fit(X_train_imp,y_train)
y_pred=lr.predict(X_test_imp)
mean_absolute_error(y_pred,y_test)
# Out:
# 6.451138259421783

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer=IterativeImputer(initial_strategy='median',random_state=25)
imputer.fit(X_train)
X_train_imp=imputer.transform(X_train)
X_test_imp=imputer.transform(X_test)
lr=LinearRegression()
lr.fit(X_train_imp,y_train)
y_pred=lr.predict(X_test_imp)
mean_absolute_error(y_pred,y_test)
# Out:
# 6.448873070405156
